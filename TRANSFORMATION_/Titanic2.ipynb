# %% [markdown]
# # Transformation de données - Anonymisation Titanic

# %% [markdown]
# Note importante:  Cest la elimination fisique, pas de cacher les donnes.

# %% [markdown]
# # Exercice 1 :
# En considérant le fichier data_patient.csv, procéder à la suppression de l’attribut PATIENT.

# %%
import pandas as pd


df1 = pd.read_excel("data/devoir/titanic3.xls")
pd.options.display.max_columns = None
df1.head(10)
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5       1         1                              Anderson, Mr. Harry    male
# 6       1         1                Andrews, Miss. Kornelia Theodosia  female
# 7       1         0                           Andrews, Mr. Thomas Jr    male
# 8       1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 9       1         0                          Artagaveytia, Mr. Ramon    male
#
#        age  sibsp  parch    ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0     24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2    113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2    113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2    113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2    113781  151.5500  C22 C26        S  NaN    NaN
# 5  48.0000      0      0     19952   26.5500      E12        S    3    NaN
# 6  63.0000      1      0     13502   77.9583       D7        S   10    NaN
# 7  39.0000      0      0    112050    0.0000      A36        S  NaN    NaN
# 8  53.0000      2      0     11769   51.4792     C101        S    D    NaN
# 9  71.0000      0      0  PC 17609   49.5042      NaN        C  NaN   22.0
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON
# 5                     New York, NY
# 6                       Hudson, NY
# 7                      Belfast, NI
# 8              Bayside, Queens, NY
# 9              Montevideo, Uruguay

# %%
#delete a column
df1 = df1.drop("name", axis=1)
df1
# Out:
#       pclass  survived     sex      age  sibsp  parch  ticket      fare  \
# 0          1         1  female  29.0000      0      0   24160  211.3375
# 1          1         1    male   0.9167      1      2  113781  151.5500
# 2          1         0  female   2.0000      1      2  113781  151.5500
# 3          1         0    male  30.0000      1      2  113781  151.5500
# 4          1         0  female  25.0000      1      2  113781  151.5500
# ...      ...       ...     ...      ...    ...    ...     ...       ...
# 1304       3         0  female  14.5000      1      0    2665   14.4542
# 1305       3         0  female      NaN      1      0    2665   14.4542
# 1306       3         0    male  26.5000      0      0    2656    7.2250
# 1307       3         0    male  27.0000      0      0    2670    7.2250
# 1308       3         0    male  29.0000      0      0  315082    7.8750
#
#         cabin embarked boat   body                        home.dest
# 0          B5        S    2    NaN                     St Louis, MO
# 1     C22 C26        S   11    NaN  Montreal, PQ / Chesterville, ON
# 2     C22 C26        S  NaN    NaN  Montreal, PQ / Chesterville, ON
# 3     C22 C26        S  NaN  135.0  Montreal, PQ / Chesterville, ON
# 4     C22 C26        S  NaN    NaN  Montreal, PQ / Chesterville, ON
# ...       ...      ...  ...    ...                              ...
# 1304      NaN        C  NaN  328.0                              NaN
# 1305      NaN        C  NaN    NaN                              NaN
# 1306      NaN        C  NaN  304.0                              NaN
# 1307      NaN        C  NaN    NaN                              NaN
# 1308      NaN        S  NaN    NaN                              NaN
#
# [1309 rows x 13 columns]

# %% [markdown]
# # Exercice 2 :
# En considérant le fichier adresse_patient.csv, procéder à la suppression de l’enregistrement dont le patient_ID est 83.

# %%
df1 = df1.drop(df1[ df1['ticket'] == "24160"].index)
df1.head(10)
# Out:
#    pclass  survived     sex      age  sibsp  parch    ticket      fare  \
# 0       1         1  female  29.0000      0      0     24160  211.3375
# 1       1         1    male   0.9167      1      2    113781  151.5500
# 2       1         0  female   2.0000      1      2    113781  151.5500
# 3       1         0    male  30.0000      1      2    113781  151.5500
# 4       1         0  female  25.0000      1      2    113781  151.5500
# 5       1         1    male  48.0000      0      0     19952   26.5500
# 6       1         1  female  63.0000      1      0     13502   77.9583
# 7       1         0    male  39.0000      0      0    112050    0.0000
# 8       1         1  female  53.0000      2      0     11769   51.4792
# 9       1         0    male  71.0000      0      0  PC 17609   49.5042
#
#      cabin embarked boat   body                        home.dest
# 0       B5        S    2    NaN                     St Louis, MO
# 1  C22 C26        S   11    NaN  Montreal, PQ / Chesterville, ON
# 2  C22 C26        S  NaN    NaN  Montreal, PQ / Chesterville, ON
# 3  C22 C26        S  NaN  135.0  Montreal, PQ / Chesterville, ON
# 4  C22 C26        S  NaN    NaN  Montreal, PQ / Chesterville, ON
# 5      E12        S    3    NaN                     New York, NY
# 6       D7        S   10    NaN                       Hudson, NY
# 7      A36        S  NaN    NaN                      Belfast, NI
# 8     C101        S    D    NaN              Bayside, Queens, NY
# 9      NaN        C  NaN   22.0              Montevideo, Uruguay

# %% [markdown]
# # Exercice 3 :
# En considérant le fichier data_livraison.csv, procéder au maskage de l’attribut code_postal. Le format en sortie serait de la forme : ZY* ***   où ZY sont les deux premiers digits du code postal original.

# %%
df1["ticket_coded"] = df1["ticket"].astype(str).map(lambda x:x[0:2]+"****")
df1 = df1.drop("ticket", axis=1)
df1
# Out:
#       pclass  survived     sex      age  sibsp  parch      fare    cabin  \
# 0          1         1  female  29.0000      0      0  211.3375       B5
# 1          1         1    male   0.9167      1      2  151.5500  C22 C26
# 2          1         0  female   2.0000      1      2  151.5500  C22 C26
# 3          1         0    male  30.0000      1      2  151.5500  C22 C26
# 4          1         0  female  25.0000      1      2  151.5500  C22 C26
# ...      ...       ...     ...      ...    ...    ...       ...      ...
# 1304       3         0  female  14.5000      1      0   14.4542      NaN
# 1305       3         0  female      NaN      1      0   14.4542      NaN
# 1306       3         0    male  26.5000      0      0    7.2250      NaN
# 1307       3         0    male  27.0000      0      0    7.2250      NaN
# 1308       3         0    male  29.0000      0      0    7.8750      NaN
#
#      embarked boat   body                        home.dest ticket_coded
# 0           S    2    NaN                     St Louis, MO       24****
# 1           S   11    NaN  Montreal, PQ / Chesterville, ON       11****
# 2           S  NaN    NaN  Montreal, PQ / Chesterville, ON       11****
# 3           S  NaN  135.0  Montreal, PQ / Chesterville, ON       11****
# 4           S  NaN    NaN  Montreal, PQ / Chesterville, ON       11****
# ...       ...  ...    ...                              ...          ...
# 1304        C  NaN  328.0                              NaN       26****
# 1305        C  NaN    NaN                              NaN       26****
# 1306        C  NaN  304.0                              NaN       26****
# 1307        C  NaN    NaN                              NaN       26****
# 1308        S  NaN    NaN                              NaN       31****
#
# [1306 rows x 13 columns]

# %% [markdown]
# # Exercice 4 :
# En considérant le fichier reactif_patient.csv, procéder à la pseudonymisation de Patient. La table de correspondance est la suivante : (obfuscation)

# %%
dict1 = {"female":"F","male":"M"}

df1['sex'] = df1.sex.replace(dict1)

df1
# Out:
#       pclass  survived sex      age  sibsp  parch      fare    cabin embarked  \
# 0          1         1   F  29.0000      0      0  211.3375       B5        S
# 1          1         1   M   0.9167      1      2  151.5500  C22 C26        S
# 2          1         0   F   2.0000      1      2  151.5500  C22 C26        S
# 3          1         0   M  30.0000      1      2  151.5500  C22 C26        S
# 4          1         0   F  25.0000      1      2  151.5500  C22 C26        S
# ...      ...       ...  ..      ...    ...    ...       ...      ...      ...
# 1304       3         0   F  14.5000      1      0   14.4542      NaN        C
# 1305       3         0   F      NaN      1      0   14.4542      NaN        C
# 1306       3         0   M  26.5000      0      0    7.2250      NaN        C
# 1307       3         0   M  27.0000      0      0    7.2250      NaN        C
# 1308       3         0   M  29.0000      0      0    7.8750      NaN        S
#
#      boat   body                        home.dest ticket_coded
# 0       2    NaN                     St Louis, MO       24****
# 1      11    NaN  Montreal, PQ / Chesterville, ON       11****
# 2     NaN    NaN  Montreal, PQ / Chesterville, ON       11****
# 3     NaN  135.0  Montreal, PQ / Chesterville, ON       11****
# 4     NaN    NaN  Montreal, PQ / Chesterville, ON       11****
# ...   ...    ...                              ...          ...
# 1304  NaN  328.0                              NaN       26****
# 1305  NaN    NaN                              NaN       26****
# 1306  NaN  304.0                              NaN       26****
# 1307  NaN    NaN                              NaN       26****
# 1308  NaN    NaN                              NaN       31****
#
# [1306 rows x 13 columns]

# %% [markdown]
# # Exercice 5:
# En considérant le fichier data_patient_age.csv, procéder à une anonymisation de la série age en utilisant les intervalles d’age au lieu de l’age exact. La table d’intervalle est la suivante :

# %%
df1['age_interval'] = df1['age'].map(lambda x: "<20" if  x< 20 
                                     else "20-30" if x<30 
                                     else "31-40" if x < 40
                                     else "41-50" if x<50 
                                     else "> 50")
df1= df1.drop("age", axis=1)
df1
# Out:
#       pclass  survived sex  sibsp  parch      fare    cabin embarked boat  \
# 0          1         1   F      0      0  211.3375       B5        S    2
# 1          1         1   M      1      2  151.5500  C22 C26        S   11
# 2          1         0   F      1      2  151.5500  C22 C26        S  NaN
# 3          1         0   M      1      2  151.5500  C22 C26        S  NaN
# 4          1         0   F      1      2  151.5500  C22 C26        S  NaN
# ...      ...       ...  ..    ...    ...       ...      ...      ...  ...
# 1304       3         0   F      1      0   14.4542      NaN        C  NaN
# 1305       3         0   F      1      0   14.4542      NaN        C  NaN
# 1306       3         0   M      0      0    7.2250      NaN        C  NaN
# 1307       3         0   M      0      0    7.2250      NaN        C  NaN
# 1308       3         0   M      0      0    7.8750      NaN        S  NaN
#
#        body                        home.dest ticket_coded age_interval
# 0       NaN                     St Louis, MO       24****        20-30
# 1       NaN  Montreal, PQ / Chesterville, ON       11****          <20
# 2       NaN  Montreal, PQ / Chesterville, ON       11****          <20
# 3     135.0  Montreal, PQ / Chesterville, ON       11****        31-40
# 4       NaN  Montreal, PQ / Chesterville, ON       11****        20-30
# ...     ...                              ...          ...          ...
# 1304  328.0                              NaN       26****          <20
# 1305    NaN                              NaN       26****         > 50
# 1306  304.0                              NaN       26****        20-30
# 1307    NaN                              NaN       26****        20-30
# 1308    NaN                              NaN       31****        20-30
#
# [1306 rows x 13 columns]

# %% [markdown]
# # 6.  permutation elements meme column

# %%
df1 = df1.drop(columns=["parch", "body"])
df1
# Out:
#       pclass  survived sex  sibsp      fare    cabin embarked boat  \
# 0          1         1   F      0  211.3375       B5        S    2
# 1          1         1   M      1  151.5500  C22 C26        S   11
# 2          1         0   F      1  151.5500  C22 C26        S  NaN
# 3          1         0   M      1  151.5500  C22 C26        S  NaN
# 4          1         0   F      1  151.5500  C22 C26        S  NaN
# ...      ...       ...  ..    ...       ...      ...      ...  ...
# 1304       3         0   F      1   14.4542      NaN        C  NaN
# 1305       3         0   F      1   14.4542      NaN        C  NaN
# 1306       3         0   M      0    7.2250      NaN        C  NaN
# 1307       3         0   M      0    7.2250      NaN        C  NaN
# 1308       3         0   M      0    7.8750      NaN        S  NaN
#
#                             home.dest ticket_coded age_interval
# 0                        St Louis, MO       24****        20-30
# 1     Montreal, PQ / Chesterville, ON       11****          <20
# 2     Montreal, PQ / Chesterville, ON       11****          <20
# 3     Montreal, PQ / Chesterville, ON       11****        31-40
# 4     Montreal, PQ / Chesterville, ON       11****        20-30
# ...                               ...          ...          ...
# 1304                              NaN       26****          <20
# 1305                              NaN       26****         > 50
# 1306                              NaN       26****        20-30
# 1307                              NaN       26****        20-30
# 1308                              NaN       31****        20-30
#
# [1306 rows x 11 columns]

# %%
df1["re"]= df1["sex"].sample(frac=1).reset_index(drop=True)
df1
# Out:
#       pclass  survived sex  sibsp      fare    cabin embarked boat  \
# 0          1         1   F      0  211.3375       B5        S    2
# 1          1         1   M      1  151.5500  C22 C26        S   11
# 2          1         0   F      1  151.5500  C22 C26        S  NaN
# 3          1         0   M      1  151.5500  C22 C26        S  NaN
# 4          1         0   F      1  151.5500  C22 C26        S  NaN
# ...      ...       ...  ..    ...       ...      ...      ...  ...
# 1304       3         0   F      1   14.4542      NaN        C  NaN
# 1305       3         0   F      1   14.4542      NaN        C  NaN
# 1306       3         0   M      0    7.2250      NaN        C  NaN
# 1307       3         0   M      0    7.2250      NaN        C  NaN
# 1308       3         0   M      0    7.8750      NaN        S  NaN
#
#                             home.dest ticket_coded age_interval   re
# 0                        St Louis, MO       24****        20-30    M
# 1     Montreal, PQ / Chesterville, ON       11****          <20    F
# 2     Montreal, PQ / Chesterville, ON       11****          <20    M
# 3     Montreal, PQ / Chesterville, ON       11****        31-40    M
# 4     Montreal, PQ / Chesterville, ON       11****        20-30    M
# ...                               ...          ...          ...  ...
# 1304                              NaN       26****          <20    M
# 1305                              NaN       26****         > 50    F
# 1306                              NaN       26****        20-30  NaN
# 1307                              NaN       26****        20-30  NaN
# 1308                              NaN       31****        20-30  NaN
#
# [1306 rows x 12 columns]

# %% [markdown]
# # 7.  perturbation elements meme column

# %%
def myround(x, base=5):
    return base * round(x/base)

df1["re2"]= myround(df1["fare"], 5)
df1
# Out:
#       pclass  survived sex  sibsp      fare    cabin embarked boat  \
# 0          1         1   F      0  211.3375       B5        S    2
# 1          1         1   M      1  151.5500  C22 C26        S   11
# 2          1         0   F      1  151.5500  C22 C26        S  NaN
# 3          1         0   M      1  151.5500  C22 C26        S  NaN
# 4          1         0   F      1  151.5500  C22 C26        S  NaN
# ...      ...       ...  ..    ...       ...      ...      ...  ...
# 1304       3         0   F      1   14.4542      NaN        C  NaN
# 1305       3         0   F      1   14.4542      NaN        C  NaN
# 1306       3         0   M      0    7.2250      NaN        C  NaN
# 1307       3         0   M      0    7.2250      NaN        C  NaN
# 1308       3         0   M      0    7.8750      NaN        S  NaN
#
#                             home.dest ticket_coded age_interval   re    re2
# 0                        St Louis, MO       24****        20-30    M  210.0
# 1     Montreal, PQ / Chesterville, ON       11****          <20    F  150.0
# 2     Montreal, PQ / Chesterville, ON       11****          <20    M  150.0
# 3     Montreal, PQ / Chesterville, ON       11****        31-40    M  150.0
# 4     Montreal, PQ / Chesterville, ON       11****        20-30    M  150.0
# ...                               ...          ...          ...  ...    ...
# 1304                              NaN       26****          <20    M   15.0
# 1305                              NaN       26****         > 50    F   15.0
# 1306                              NaN       26****        20-30  NaN    5.0
# 1307                              NaN       26****        20-30  NaN    5.0
# 1308                              NaN       31****        20-30  NaN   10.0
#
# [1306 rows x 13 columns]

# %%
#renommer la serie age_interval vers age
df1 = df1.rename(columns={'re2': 'fareBase5'})
df1
# Out:
#       pclass  survived sex  sibsp      fare    cabin embarked boat  \
# 0          1         1   F      0  211.3375       B5        S    2
# 1          1         1   M      1  151.5500  C22 C26        S   11
# 2          1         0   F      1  151.5500  C22 C26        S  NaN
# 3          1         0   M      1  151.5500  C22 C26        S  NaN
# 4          1         0   F      1  151.5500  C22 C26        S  NaN
# ...      ...       ...  ..    ...       ...      ...      ...  ...
# 1304       3         0   F      1   14.4542      NaN        C  NaN
# 1305       3         0   F      1   14.4542      NaN        C  NaN
# 1306       3         0   M      0    7.2250      NaN        C  NaN
# 1307       3         0   M      0    7.2250      NaN        C  NaN
# 1308       3         0   M      0    7.8750      NaN        S  NaN
#
#                             home.dest ticket_coded age_interval   re  \
# 0                        St Louis, MO       24****        20-30    M
# 1     Montreal, PQ / Chesterville, ON       11****          <20    F
# 2     Montreal, PQ / Chesterville, ON       11****          <20    M
# 3     Montreal, PQ / Chesterville, ON       11****        31-40    M
# 4     Montreal, PQ / Chesterville, ON       11****        20-30    M
# ...                               ...          ...          ...  ...
# 1304                              NaN       26****          <20    M
# 1305                              NaN       26****         > 50    F
# 1306                              NaN       26****        20-30  NaN
# 1307                              NaN       26****        20-30  NaN
# 1308                              NaN       31****        20-30  NaN
#
#       fareBase5
# 0         210.0
# 1         150.0
# 2         150.0
# 3         150.0
# 4         150.0
# ...         ...
# 1304       15.0
# 1305       15.0
# 1306        5.0
# 1307        5.0
# 1308       10.0
#
# [1306 rows x 13 columns]
