# %% [markdown]
# # TP - Transformation de donnes
# Ricardo Vallejo

# %% [markdown]
# # <font color="blue"> Étape 1 : </font>
# On considère le fichier train_users_2.csv

# %% [markdown]
# ## 1. Import Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.impute import SimpleImputer

# %%
data = pd.read_csv('train_users_2.csv')
data
# Out:
#                 id date_account_created  timestamp_first_active  \
# 0       gxn3p5htnn           2010-06-28          20090319043255
# 1       820tgsjxq7           2011-05-25          20090523174809
# 2       4ft3gnwmtx           2010-09-28          20090609231247
# 3       bjjt8pjhuk           2011-12-05          20091031060129
# 4       87mebub9p4           2010-09-14          20091208061105
# ...            ...                  ...                     ...
# 213446  zxodksqpep           2014-06-30          20140630235636
# 213447  mhewnxesx9           2014-06-30          20140630235719
# 213448  6o3arsjbb4           2014-06-30          20140630235754
# 213449  jh95kwisub           2014-06-30          20140630235822
# 213450  nw9fwlyb5f           2014-06-30          20140630235824
#
#        date_first_booking     gender   age signup_method  signup_flow  \
# 0                     NaN  -unknown-   NaN      facebook            0
# ...

# %% [markdown]
# ## 2. Responses

# %% [markdown]
# ###   a) Quelles sont les descripteurs (colonnes) du dataset?

# %%
descripteurs = data.columns
descripteurs = pd.DataFrame(descripteurs)
descripteurs
# Out:
#                           0
# 0                        id
# 1      date_account_created
# 2    timestamp_first_active
# 3        date_first_booking
# 4                    gender
# 5                       age
# 6             signup_method
# 7               signup_flow
# 8                  language
# 9         affiliate_channel
# 10       affiliate_provider
# 11  first_affiliate_tracked
# 12               signup_app
# 13        first_device_type
# 14            first_browser
# 15      country_destination

# %% [markdown]
# ### b) Combien d'enregistrements (lignes) ont été fournis ?

# %%
nrows = data.shape[0]
nrows
# Out:
# 213451

# %% [markdown]
# ### c)
# ●	Y a-t-il des valeurs manquantes?
#
# ●	Est-ce qu’il y’a des dépendances évidentes au niveau des descripteurs?
#
# ●	Quel est le format des données. Par exemple, dans quel format les dates sont fournies, existe-t-il des valeurs numériques,
# à quoi ressemblent les différentes valeurs catégorielles ?

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213451 entries, 0 to 213450
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   id                       213451 non-null  object
#  1   date_account_created     213451 non-null  object
#  2   timestamp_first_active   213451 non-null  int64
#  3   date_first_booking       88908 non-null   object
#  4   gender                   213451 non-null  object
#  5   age                      125461 non-null  float64
#  6   signup_method            213451 non-null  object
#  7   signup_flow              213451 non-null  int64
#  8   language                 213451 non-null  object
#  9   affiliate_channel        213451 non-null  object
#  10  affiliate_provider       213451 non-null  object
#  11  first_affiliate_tracked  207386 non-null  object
#  12  signup_app               213451 non-null  object
# ...

# %%
responses = pd.read_excel('TP_response.xlsx', sheet_name='Response')
responses
# Out:
#                  Descriptor Format Original Format Final Type de donne  \
# 0                        id         object       String              -
# 1      date_account_created         object          Date           NaN
# 2    timestamp_first_active           int64     DateTime             -
# 3        date_first_booking         object      DateTime             -
# 4                    gender         object        String             -
# 5                       age           float      Integer     Numerique
# 6             signup_method         object       Integer     Numerique
# 7               signup_flow           int64      Integer     Numerique
# 8                  language         object        String   Categorical
# 9         affiliate_channel         object        String   Categorical
# 10       affiliate_provider         object        String   Categorical
# 11  first_affiliate_tracked         object        String   Categorical
# ...

# %% [markdown]
# # <font color="blue"> Étape 2 : </font>
# On considère les fichiers train_users_2.csv and test_users.csv

# %% [raw]
# ●	Conversion de type/format
# ●	Remplacement de valeurs manquantes
# ●	Correction/Suppression de valeurs aberrantes/erronées
# ●	Correction/Standardisation/Normalisation de données

# %% [markdown]
# ### <font color="red"> a) Id </font>

# %%
# There are not duplicated values in Id

boolean = data['id'].duplicated().any()
boolean
# Out:
# False

# %%
# Convert from object to String

dataFinal = data
dataFinal['id'] = dataFinal['id'].astype(str)
dataFinal
# Out:
#                 id date_account_created  timestamp_first_active  \
# 0       gxn3p5htnn           2010-06-28          20090319043255
# 1       820tgsjxq7           2011-05-25          20090523174809
# 2       4ft3gnwmtx           2010-09-28          20090609231247
# 3       bjjt8pjhuk           2011-12-05          20091031060129
# 4       87mebub9p4           2010-09-14          20091208061105
# ...            ...                  ...                     ...
# 213446  zxodksqpep           2014-06-30          20140630235636
# 213447  mhewnxesx9           2014-06-30          20140630235719
# 213448  6o3arsjbb4           2014-06-30          20140630235754
# 213449  jh95kwisub           2014-06-30          20140630235822
# 213450  nw9fwlyb5f           2014-06-30          20140630235824
#
#        date_first_booking     gender   age signup_method  signup_flow  \
# 0                     NaN  -unknown-   NaN      facebook            0
# ...

# %%
# Detecting initial types and null values presence

dataFinal.info()  #TODO ID dont change to String ?????
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213451 entries, 0 to 213450
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   id                       213451 non-null  object
#  1   date_account_created     213451 non-null  object
#  2   timestamp_first_active   213451 non-null  int64
#  3   date_first_booking       88908 non-null   object
#  4   gender                   213451 non-null  object
#  5   age                      125461 non-null  float64
#  6   signup_method            213451 non-null  object
#  7   signup_flow              213451 non-null  int64
#  8   language                 213451 non-null  object
#  9   affiliate_channel        213451 non-null  object
#  10  affiliate_provider       213451 non-null  object
#  11  first_affiliate_tracked  207386 non-null  object
#  12  signup_app               213451 non-null  object
# ...

# %%
# There are not Null values present
boolean = data['id'].isnull()
any(boolean) #To identify if any true
# Out:
# False

# %% [markdown]
# ### <font color="red"> b) 'date_account_created' </font>

# %%
dataFinal['date_account_created'] =  pd.to_datetime(dataFinal['date_account_created'])
dataFinal.head(5)
# Out:
#            id date_account_created  timestamp_first_active date_first_booking  \
# 0  gxn3p5htnn           2010-06-28          20090319043255                NaN
# 1  820tgsjxq7           2011-05-25          20090523174809                NaN
# 2  4ft3gnwmtx           2010-09-28          20090609231247         2010-08-02
# 3  bjjt8pjhuk           2011-12-05          20091031060129         2012-09-08
# 4  87mebub9p4           2010-09-14          20091208061105         2010-02-18
#
#       gender   age signup_method  signup_flow language affiliate_channel  \
# 0  -unknown-   NaN      facebook            0       en            direct
# 1       MALE  38.0      facebook            0       en               seo
# 2     FEMALE  56.0         basic            3       en            direct
# 3     FEMALE  42.0      facebook            0       en            direct
# 4  -unknown-  41.0         basic            0       en            direct
#
# ...

# %%
dataFinal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213451 entries, 0 to 213450
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   id                       213451 non-null  object
#  1   date_account_created     213451 non-null  datetime64[ns]
#  2   timestamp_first_active   213451 non-null  int64
#  3   date_first_booking       88908 non-null   object
#  4   gender                   213451 non-null  object
#  5   age                      125461 non-null  float64
#  6   signup_method            213451 non-null  object
#  7   signup_flow              213451 non-null  int64
#  8   language                 213451 non-null  object
#  9   affiliate_channel        213451 non-null  object
#  10  affiliate_provider       213451 non-null  object
#  11  first_affiliate_tracked  207386 non-null  object
#  12  signup_app               213451 non-null  object
# ...

# %%
dataFinal['date_account_created'].describe()
# Out:
# <ipython-input-247-f7cf22fe714b>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   dataFinal['date_account_created'].describe()
# count                  213451
# unique                   1634
# top       2014-05-13 00:00:00
# freq                      674
# first     2010-01-01 00:00:00
# last      2014-06-30 00:00:00
# Name: date_account_created, dtype: object

# %% [markdown]
# ## <font color="red"> c)  timestamp_first_active </font>

# %% [markdown]
# ### Convert objet to DateTime with correct format

# %%
dataFinal['timestamp_first_active']
# Out:
# 0         20090319043255
# 1         20090523174809
# 2         20090609231247
# 3         20091031060129
# 4         20091208061105
#                ...
# 213446    20140630235636
# 213447    20140630235719
# 213448    20140630235754
# 213449    20140630235822
# 213450    20140630235824
# Name: timestamp_first_active, Length: 213451, dtype: int64

# %%
from datetime import datetime

dataFinal['timestamp_first_active'] = pd.to_datetime(dataFinal['timestamp_first_active'], format='%Y%m%d%H%M%S')
dataFinal.head(5)
# Out:
#            id date_account_created timestamp_first_active date_first_booking  \
# 0  gxn3p5htnn           2010-06-28    2009-03-19 04:32:55                NaN
# 1  820tgsjxq7           2011-05-25    2009-05-23 17:48:09                NaN
# 2  4ft3gnwmtx           2010-09-28    2009-06-09 23:12:47         2010-08-02
# 3  bjjt8pjhuk           2011-12-05    2009-10-31 06:01:29         2012-09-08
# 4  87mebub9p4           2010-09-14    2009-12-08 06:11:05         2010-02-18
#
#       gender   age signup_method  signup_flow language affiliate_channel  \
# 0  -unknown-   NaN      facebook            0       en            direct
# 1       MALE  38.0      facebook            0       en               seo
# 2     FEMALE  56.0         basic            3       en            direct
# 3     FEMALE  42.0      facebook            0       en            direct
# 4  -unknown-  41.0         basic            0       en            direct
#
# ...

# %%
# Detection donnes aberrantes et validation de format

# %%
dataFinal['timestamp_first_active'].describe()
# Out:
# <ipython-input-251-0fcdf438e6dd>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   dataFinal['timestamp_first_active'].describe()
# count                  213451
# unique                 213451
# top       2013-08-17 12:28:31
# freq                        1
# first     2009-03-19 04:32:55
# last      2014-06-30 23:58:24
# Name: timestamp_first_active, dtype: object

# %%
# Split

# %%
dataFinal['year_tfc'] = dataFinal['timestamp_first_active'].dt.year
dataFinal['month_tfc'] = dataFinal['timestamp_first_active'].dt.month
dataFinal['day_tfc'] = dataFinal['timestamp_first_active'].dt.day
dataFinal
# Out:
#                 id date_account_created timestamp_first_active  \
# 0       gxn3p5htnn           2010-06-28    2009-03-19 04:32:55
# 1       820tgsjxq7           2011-05-25    2009-05-23 17:48:09
# 2       4ft3gnwmtx           2010-09-28    2009-06-09 23:12:47
# 3       bjjt8pjhuk           2011-12-05    2009-10-31 06:01:29
# 4       87mebub9p4           2010-09-14    2009-12-08 06:11:05
# ...            ...                  ...                    ...
# 213446  zxodksqpep           2014-06-30    2014-06-30 23:56:36
# 213447  mhewnxesx9           2014-06-30    2014-06-30 23:57:19
# 213448  6o3arsjbb4           2014-06-30    2014-06-30 23:57:54
# 213449  jh95kwisub           2014-06-30    2014-06-30 23:58:22
# 213450  nw9fwlyb5f           2014-06-30    2014-06-30 23:58:24
#
#        date_first_booking     gender   age signup_method  signup_flow  \
# 0                     NaN  -unknown-   NaN      facebook            0
# ...

# %% [markdown]
# ## <font color="red"> d) date_first_booking</font>

# %%
# Giving date format

dataFinal['date_first_booking'] = pd.to_datetime(dataFinal['date_first_booking'], format='%Y-%m-%d')
dataFinal
# Out:
#                 id date_account_created timestamp_first_active  \
# 0       gxn3p5htnn           2010-06-28    2009-03-19 04:32:55
# 1       820tgsjxq7           2011-05-25    2009-05-23 17:48:09
# 2       4ft3gnwmtx           2010-09-28    2009-06-09 23:12:47
# 3       bjjt8pjhuk           2011-12-05    2009-10-31 06:01:29
# 4       87mebub9p4           2010-09-14    2009-12-08 06:11:05
# ...            ...                  ...                    ...
# 213446  zxodksqpep           2014-06-30    2014-06-30 23:56:36
# 213447  mhewnxesx9           2014-06-30    2014-06-30 23:57:19
# 213448  6o3arsjbb4           2014-06-30    2014-06-30 23:57:54
# 213449  jh95kwisub           2014-06-30    2014-06-30 23:58:22
# 213450  nw9fwlyb5f           2014-06-30    2014-06-30 23:58:24
#
#        date_first_booking     gender   age signup_method  signup_flow  \
# 0                     NaT  -unknown-   NaN      facebook            0
# ...

# %%
# Fill null values with oldest.

dataFinal['date_first_booking'] = dataFinal['date_first_booking'].fillna(dataFinal['date_first_booking'].min()) 

#To assing min date because the oldest first booking has not promos and its possible.

dataFinal
# Out:
#                 id date_account_created timestamp_first_active  \
# 0       gxn3p5htnn           2010-06-28    2009-03-19 04:32:55
# 1       820tgsjxq7           2011-05-25    2009-05-23 17:48:09
# 2       4ft3gnwmtx           2010-09-28    2009-06-09 23:12:47
# 3       bjjt8pjhuk           2011-12-05    2009-10-31 06:01:29
# 4       87mebub9p4           2010-09-14    2009-12-08 06:11:05
# ...            ...                  ...                    ...
# 213446  zxodksqpep           2014-06-30    2014-06-30 23:56:36
# 213447  mhewnxesx9           2014-06-30    2014-06-30 23:57:19
# 213448  6o3arsjbb4           2014-06-30    2014-06-30 23:57:54
# 213449  jh95kwisub           2014-06-30    2014-06-30 23:58:22
# 213450  nw9fwlyb5f           2014-06-30    2014-06-30 23:58:24
#
#        date_first_booking     gender   age signup_method  signup_flow  \
# 0              2010-01-02  -unknown-   NaN      facebook            0
# ...

# %%
# Detect outliers data

# %%
dataFinal['date_first_booking'].describe()
# Out:
# <ipython-input-258-2b6d64f075af>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   dataFinal['date_first_booking'].describe()
# count                  213451
# unique                   1976
# top       2010-01-02 00:00:00
# freq                   124544
# first     2010-01-02 00:00:00
# last      2015-06-29 00:00:00
# Name: date_first_booking, dtype: object
